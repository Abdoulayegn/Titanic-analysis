# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
s=pd.Series(np.random.randn(50))
s.head()
# Out:
# 0   -0.567201
# 1    0.107958
# 2   -0.153215
# 3   -0.805467
# 4    0.692375
# dtype: float64

# %%
df=pd.DataFrame(np.random.randn(50,6),columns=list('ABCDEF'))
df.head()
# Out:
#           A         B         C         D         E         F
# 0 -0.011980  1.589286 -0.666381 -0.241724  1.092588  0.538795
# 1  0.226193 -0.152041  0.576336  0.925727 -0.865351 -1.247913
# 2 -0.018443  1.208965  0.561091 -0.806616  0.313077 -0.988542
# 3 -0.592755 -0.328092 -0.343165  1.058371 -0.941617 -0.713385
# 4 -0.451995  2.123292 -1.176059  1.106097 -0.918868  1.256114

# %%
plt.plot(s)
plt.show()

# %%
plt.barh(s,width=7)
plt.show()

# %%
plt.plot(df)
plt.show()

# %%
a=df['A']
b=df['B']
a.head()
b.head()
# Out:
# 0    1.589286
# 1   -0.152041
# 2    1.208965
# 3   -0.328092
# 4    2.123292
# Name: B, dtype: float64

# %%
plt.scatter(a,b)
plt.show()

# %%
plt.bar(a,b)
plt.show()

# %%
plt.hist(a)
plt.hist(b)
plt.show()

# %%
plt.barh(a,width = 7)
plt.show()

# %%
plt.plot(a)
plt.show()

# %%
plt.plot(b)
plt.show()

# %%
df.describe()
# Out:
#                A          B          C          D          E          F
# count  50.000000  50.000000  50.000000  50.000000  50.000000  50.000000
# mean   -0.041740   0.105828  -0.156428   0.064680   0.029472   0.015396
# std     0.810075   1.078373   1.022131   0.753240   1.077044   0.841106
# min    -1.631689  -1.806190  -2.185211  -1.332510  -2.539152  -1.594219
# 25%    -0.591420  -0.662181  -1.001144  -0.426455  -0.905489  -0.629493
# 50%    -0.010380  -0.068367   0.034997   0.069883  -0.004997   0.041732
# 75%     0.533910   0.895800   0.568746   0.558994   0.974651   0.622099
# max     1.663932   3.046667   1.748559   1.818327   2.228210   1.699566

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
a=np.arange(0.1,4,0.5)
b=np.exp(-a)
plt.plot(a,b)
plt.show()

# %%
plt.bar(a,height=7)
plt.show()

# %%
plt.plot(b)
plt.show()

# %%
plt.plot(a)
plt.show()

# %%
#plt.plot(x,y)
#plt.show()

# %% [markdown]
# ## Missing value handling  using drop, fillna and imp

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('http://bit.ly/uforeports')
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.dropna().head()
# Out:
#           City Colors Reported Shape Reported State             Time
# 12      Belton             RED         SPHERE    SC  6/30/1939 20:00
# 19  Bering Sea             RED          OTHER    AK  4/30/1943 23:00
# 36  Portsmouth             RED      FORMATION    VA   7/10/1945 1:30
# 44   Blairsden           GREEN         SPHERE    CA  6/30/1946 19:00
# 82    San Jose            BLUE        CHEVRON    CA  7/15/1947 21:00

# %%
df.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
df.isna().head()
# Out:
#     City  Colors Reported  Shape Reported  State   Time
# 0  False             True           False  False  False
# 1  False             True           False  False  False
# 2  False             True           False  False  False
# 3  False             True           False  False  False
# 4  False             True           False  False  False

# %%
data=df.fillna(method = 'ffill')
# we can see that as the this row was NaN while using forward filling we will get nan for all other the follow
# to handle this let us the mean of because when we replace them by zero it want look goog in point ofview.
data.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca             NaN       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro             NaN          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke             NaN           OVAL    CO  2/15/1931 14:00
# 3               Abilene             NaN           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair             NaN          LIGHT    NY  4/18/1933 19:00

# %%
data=df.fillna(value = -999)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data.head()
# Out:
#                    City Colors Reported Shape Reported State             Time
# 0                Ithaca            -999       TRIANGLE    NY   6/1/1930 22:00
# 1           Willingboro            -999          OTHER    NJ  6/30/1930 20:00
# 2               Holyoke            -999           OVAL    CO  2/15/1931 14:00
# 3               Abilene            -999           DISK    KS   6/1/1931 13:00
# 4  New York Worlds Fair            -999          LIGHT    NY  4/18/1933 19:00

# %%
data.City.value_counts().plot(kind = 'bar' )
